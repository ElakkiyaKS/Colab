# %%
#Mark and Grade finder
mark = int(input("Enter your mark:"))
if mark >91 and mark<100:
           print("A")
elif mark >81 and mark<90:
           print("B")
elif mark >71 and mark<80:
           print("c")
elif mark >61 and mark<70:
           print("D")
else:
           print("E")
# Out:
# Enter your mark:66
# D

# %%
# to find prime number
num = int(input("Enter a number:"))
for i in range(2,num):
 if (num%i) == 0:
      print("its not a prime number")
      break
 else:
      print("its a prime number")
      break
# Out:
# Enter a number:11
# its a prime number

# %%
# to add two numbers without "+" operator
a = 5
b = 10
c = a-(-b)
print(c)
# Out:
# 15

# %% [markdown]
# j

# %%
# to add two numbers without arithmetic operator
print(sum([5,35]))
# Out:
# 40

# %%
# convert celcius to farenheit
n1 = int(input("enter the celcius:"))
n2 = n1*(1.8+32)
print(n2)
# Out:
# enter the celcius:5
# 169.0
